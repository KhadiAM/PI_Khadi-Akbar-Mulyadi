# %%
# ================================================
# SISTEM REKOMENDASI BERITA (TF-IDF + CLUSTER)
# ================================================

# 1. Import Library
import pandas as pd
import numpy as np
import re
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans

# ================================================
# 2. Load Dataset
# ================================================
df = pd.read_csv("politik_merge.csv")   # ganti sesuai dataset kamu
print("Jumlah data awal:", len(df))
print(df.head())

# ================================================
# 3. Preprocessing sederhana
# ================================================
def clean_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'\d+', '', text)       # hapus angka
        text = re.sub(r'\W+', ' ', text)      # hapus simbol
        text = re.sub(r'\s+', ' ', text)      # hapus spasi berlebih
        return text.strip()
    return ""

df["cleaned"] = df["Content"].astype(str).apply(clean_text)

# Gabungkan judul + konten agar lebih representatif
df["combined"] = df["Judul"].astype(str) + " " + df["cleaned"]

print("\nContoh teks setelah preprocessing:\n")
print(df[["Judul", "combined"]].head())

# ================================================
# 4. Clustering dengan KMeans
# ================================================
vectorizer_cluster = TfidfVectorizer(max_features=3000)
X_cluster = vectorizer_cluster.fit_transform(df["combined"])

# jumlah cluster bisa disesuaikan, misal 10 topik
kmeans = KMeans(n_clusters=10, random_state=42, n_init=10)
df["Cluster"] = kmeans.fit_predict(X_cluster)

print("\nDistribusi cluster:")
print(df["Cluster"].value_counts())

# Simpan dataset dengan cluster
df.to_csv("news_with_cluster.csv", index=False)
print("\nFile 'news_with_cluster.csv' berhasil disimpan!")

# ================================================
# 5. TF-IDF Vectorization (untuk rekomendasi)
# ================================================
vectorizer = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1,3)   # unigram, bigram, trigram
)
tfidf_matrix = vectorizer.fit_transform(df["combined"])
print("\nTF-IDF matrix shape:", tfidf_matrix.shape)

# ================================================
# 6. Simpan Model & Data
# ================================================
pickle.dump(vectorizer, open("tfidf_vectorizer.pkl", "wb"))
pickle.dump(tfidf_matrix, open("tfidf_matrix.pkl", "wb"))

print("\nFile model berhasil disimpan!")

# ================================================
# 7. Fungsi Rekomendasi (Cluster-Aware)
# ================================================
def get_recommendations(title, top_n=5):
    if title not in df["Judul"].values:
        return ["Judul tidak ditemukan"]

    idx = df[df["Judul"] == title].index[0]
    cluster_id = df.iloc[idx]["Cluster"]

    # pilih subset artikel dalam cluster yang sama
    subset_idx = df[df["Cluster"] == cluster_id].index
    subset_matrix = tfidf_matrix[subset_idx]

    # hitung cosine similarity hanya dalam cluster
    cosine_sim = cosine_similarity(tfidf_matrix[idx], subset_matrix).flatten()

    # urutkan berdasarkan skor similarity
    similar_idx = cosine_sim.argsort()[::-1]

    # ambil top_n (skip indeks 0 = dirinya sendiri)
    similar_idx = similar_idx[1:top_n+1]
    rekomendasi_idx = subset_idx[similar_idx]

    return df.iloc[rekomendasi_idx][["Judul", "Cluster"]]

# ================================================
# 8. Uji Coba Rekomendasi
# ================================================
contoh_judul = df["Judul"].iloc[0]
print("\nJudul dipilih:", contoh_judul)
print("\nRekomendasi:")
print(get_recommendations(contoh_judul, top_n=5))
# Out:
# Jumlah data awal: 45781
#                                                Judul  \
# 0  Jokowi Kenakan Pakaian Adat Betawi di Sidang T...
# 1  Amnesty International Beberkan 6 Indikator Kri...
# 2  Jelang Long Weekend, Stasiun Kereta Cepat Hali...
# 3  KPU Tegaskan Pemilih Tak Terdaftar di DPT Bisa...
# 4  Kemenag Luncurkan Gerakan Senam Haji Jaga Keta...
#
#                           Waktu  \
# 0                    16/08/2024
# 1                    2024-07-18
# 2  Rabu, 08 Mei  2024 19:18 WIB
# 3                    13/02/2024
# 4                    2024-04-29
#
#                                                 Link  \
# 0  https://nasional.kompas.com/read/2024/08/16/11...
# 1  https://nasional.tempo.co/read/1893144/amnesty...
# 2  https://news.detik.com/berita/d-7331666/jelang...
# 3  https://nasional.kompas.com/read/2024/02/13/21...
# 4  https://nasional.tempo.co/read/1861810/kemenag...
#
#                                              Content                   tag1  \
# 0   JAKARTA, KOMPAS.com - Presiden Joko Widodo me...        Presiden Jokowi
# 1  TEMPO.CO, Jakarta - Amnesty International Indo...  Amnesty International
# 2  Stasiun kereta cepat Whoosh di Halim, Jakarta ...    kereta cepat whoosh
# 3   JAKARTA, KOMPAS.com - Komisi Pemilihan Umum (...                    KPU
# 4  TEMPO.CO, Jakarta - Kementerian Agama atau Kem...             Senam Haji
#
#                                tag2                        tag3  \
# 0                            Jokowi  sidang tahunan MPR RI 2024
# 1  Amnesty International Indonesia        Kebebasan Berpendapat
# 2                     stasiun halim                long weekend
# 3                       pemilu 2024              Hasyim Asy'ari
# 4                           Kemenag                 Jemaah Haji
#
#                                  tag4  \
# 0  Jokowi adat Betawi sidang mpr 2024
# 1                   Indeks Demokrasi
# 2                                 NaN
# 3                                 NaN
# 4                         Ibadah Haji
#
#                                           tag5  source
# 0  Megawati tak hadiri sidang tahunan MPR 2024  kompas
# 1                                Revisi UU TNI   tempo
# 2                                          NaN   detik
# 3                                          NaN  kompas
# 4                                  Asrama Haji   tempo
#
# Contoh teks setelah preprocessing:
#
#                                                Judul  \
# 0  Jokowi Kenakan Pakaian Adat Betawi di Sidang T...
# 1  Amnesty International Beberkan 6 Indikator Kri...
# 2  Jelang Long Weekend, Stasiun Kereta Cepat Hali...
# 3  KPU Tegaskan Pemilih Tak Terdaftar di DPT Bisa...
# 4  Kemenag Luncurkan Gerakan Senam Haji Jaga Keta...
#
#                                             combined
# 0  Jokowi Kenakan Pakaian Adat Betawi di Sidang T...
# 1  Amnesty International Beberkan 6 Indikator Kri...
# 2  Jelang Long Weekend, Stasiun Kereta Cepat Hali...
# 3  KPU Tegaskan Pemilih Tak Terdaftar di DPT Bisa...
# 4  Kemenag Luncurkan Gerakan Senam Haji Jaga Keta...
# C:\Users\user\AppData\Roaming\Python\Python312\site-packages\joblib\externals\loky\backend\context.py:150: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\user\AppData\Roaming\Python\Python312\site-packages\joblib\externals\loky\backend\context.py", line 227, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Distribusi cluster:
# Cluster
# 1    18499
# 0     5348
# 7     4200
# 5     4042
# 2     3970
# 9     2986
# 3     2359
# 4     1875
# 6     1330
# 8     1172
# Name: count, dtype: int64
#
# TF-IDF matrix shape: (45781, 10000)
#
# File model berhasil disimpan!
#
# Judul dipilih: Jokowi Kenakan Pakaian Adat Betawi di Sidang Tahunan Terakhirnya, Simbol Terima Kasih untuk Jakarta
#
# Rekomendasi:
#                                                    Judul  Cluster
# 43449  KSP: Pakaian Adat Betawi Presiden Simbol Terim...        2
# 18064  7 Pakaian Adat yang Dikenakan Jokowi Saat Pida...        2
# 37856  Daftar Baju Adat Jokowi Tiap Sidang Tahunan, T...        2
# 33840  Tentang Baju Kustin, Pakaian Adat Jokowi Saat ...        2
# 28826  Jokowi di HUT RI IKN, Pakai Baju Adat Nusantar...        2
